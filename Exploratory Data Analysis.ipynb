# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %% [raw]
# Variable Identification:
# There are two types of variable-
# Quantitative Variable:They can be measured in numbers.
# Categorical Variable:They cannot be measured in numbers.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('final.csv')
data
# Out:
#       S_number                              Name    Location  Year  \
# 0            0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1            1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2            2                      Honda Jazz V     Chennai  2011
# 3            3                 Maruti Ertiga VDI     Chennai  2012
# 4            4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...        ...                               ...         ...   ...
# 6014      6014                  Maruti Swift VDI       Delhi  2014
# 6015      6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016      6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017      6017                Maruti Wagon R VXI     Kolkata  2013
# 6018      6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage(kmpl)  \
# 0                 72000       CNG       Manual      First          26.60
# ...

# %%
df=pd.DataFrame(data)
df.head()
# Out:
#    S_number                              Name    Location  Year  \
# 0         0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1         1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2         2                      Honda Jazz V     Chennai  2011
# 3         3                 Maruti Ertiga VDI     Chennai  2012
# 4         4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage(kmpl)  \
# 0              72000       CNG       Manual      First          26.60
# 1              41000    Diesel       Manual      First          19.67
# 2              46000    Petrol       Manual      First          18.20
# 3              87000    Diesel       Manual      First          20.77
# 4              40670    Diesel    Automatic     Second          15.20
#
#    Engine(CC) Power(bhp)  Seats  New_Price  Price paint_color         type  \
# 0       998.0      58.16    5.0        NaN   1.75        blue        other
# ...

# %%
data.describe
# Out:
# <bound method NDFrame.describe of       S_number                              Name    Location  Year  \
# 0            0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1            1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2            2                      Honda Jazz V     Chennai  2011
# 3            3                 Maruti Ertiga VDI     Chennai  2012
# 4            4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...        ...                               ...         ...   ...
# 6014      6014                  Maruti Swift VDI       Delhi  2014
# 6015      6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016      6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017      6017                Maruti Wagon R VXI     Kolkata  2013
# 6018      6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage(kmpl)  \
# ...

# %%
to_drop=['S_number','New_Price']
data.drop(to_drop,inplace=True,axis='columns')

# %%
data.columns
# Out:
# Index(['Name', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#        'Transmission', 'Owner_Type', 'Mileage(kmpl)', 'Engine(CC)',
#        'Power(bhp)', 'Seats', 'Price', 'paint_color', 'type', 'condition'],
#       dtype='object')

# %%
dup=data.drop_duplicates(['Name','Location','Year','Kilometers_Driven','Fuel_Type', 'Transmission','Owner_Type','Mileage(kmpl)',
       'Engine(CC)','Power(bhp)', 'Seats','Price','paint_color', 'type', 'condition'])
dup
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
# ...

# %% [markdown]
# # Categorical Variables:
# Name,Location,Fuel_Type,Transmission,Owner_Type,paint_color
#
# Quantitative Variables:
# Kilometers_Driven,Mileage(kmpl),Engine(CC),Power(bhp),Seats,Price

# %% [markdown]
# # Univariate Analysis
# Method to perform uni-variate analysis will depend on whether the variable type is categorical or continuous.
# Continuous Variables:- In case of continuous variables, we need to understand the central tendency and spread of the variable.

# %%
dup.mean()
# Out:
# Year                  2013.358199
# Kilometers_Driven    58738.380296
# Mileage(kmpl)           18.138744
# Engine(CC)            1621.276450
# Seats                    5.278735
# Price                    9.479468
# dtype: float64

# %%
dup.median()
# Out:
# Year                  2014.00
# Kilometers_Driven    53000.00
# Mileage(kmpl)           18.15
# Engine(CC)            1493.00
# Seats                    5.00
# Price                    5.64
# dtype: float64

# %%
dup.mode()
# Out:
#                      Name Location  Year  Kilometers_Driven Fuel_Type  \
# 0  Mahindra XUV500 W8 2WD   Mumbai  2014              60000    Diesel
#
#   Transmission Owner_Type  Mileage(kmpl)  Engine(CC) Power(bhp)  Seats  Price  \
# 0       Manual      First           17.0      1197.0         74    5.0    4.5
#
#   paint_color   type condition
# 0       white  sedan      good

# %%
dup.std(ddof=0)
# Out:
# Year                     3.269470
# Kilometers_Driven    91261.261163
# Mileage(kmpl)            4.567618
# Engine(CC)             601.304975
# Seats                    0.808772
# Price                   11.186988
# dtype: float64

# %%
from scipy import stats
stats.variation(dup.mean(),axis=0)
# Out:
# 2.079853474056609

# %%
data.Name
# Out:
# 0                 Maruti Wagon R LXI CNG
# 1       Hyundai Creta 1.6 CRDi SX Option
# 2                           Honda Jazz V
# 3                      Maruti Ertiga VDI
# 4        Audi A4 New 2.0 TDI Multitronic
#                       ...
# 6014                    Maruti Swift VDI
# 6015            Hyundai Xcent 1.1 CRDi S
# 6016               Mahindra Xylo D4 BSIV
# 6017                  Maruti Wagon R VXI
# 6018               Chevrolet Beat Diesel
# Name: Name, Length: 6019, dtype: object

# %%
data.groupby('Name').first()
# Out:
#                                  Location  Year  Kilometers_Driven Fuel_Type  \
# Name
# Ambassador Classic Nova Diesel    Chennai  2003              80000    Diesel
# Audi A3 35 TDI Attraction         Chennai  2014              79271    Diesel
# Audi A3 35 TDI Premium             Mumbai  2016              20003    Diesel
# Audi A3 35 TDI Premium Plus        Mumbai  2016              39000    Diesel
# Audi A3 35 TDI Technology           Delhi  2017              22000    Diesel
# ...                                   ...   ...                ...       ...
# Volvo XC60 D4 Summum            Hyderabad  2012              86000    Diesel
# Volvo XC60 D5                        Pune  2011             106976    Diesel
# Volvo XC60 D5 Inscription           Kochi  2014              86925    Diesel
# Volvo XC90 2007-2015 D5 AT AWD      Kochi  2014             102001    Diesel
# Volvo XC90 2007-2015 D5 AWD         Kochi  2014              89230    Diesel
#
# ...

# %%
x=dup.head().groupby('Name').count()
x
# Out:
#                                   Location  Year  Kilometers_Driven  \
# Name
# Audi A4 New 2.0 TDI Multitronic          1     1                  1
# Honda Jazz V                             1     1                  1
# Hyundai Creta 1.6 CRDi SX Option         1     1                  1
# Maruti Ertiga VDI                        1     1                  1
# Maruti Wagon R LXI CNG                   1     1                  1
#
#                                   Fuel_Type  Transmission  Owner_Type  \
# Name
# Audi A4 New 2.0 TDI Multitronic           1             1           1
# Honda Jazz V                              1             1           1
# Hyundai Creta 1.6 CRDi SX Option          1             1           1
# Maruti Ertiga VDI                         1             1           1
# Maruti Wagon R LXI CNG                    1             1           1
#
#                                   Mileage(kmpl)  Engine(CC)  Power(bhp)  \
# Name
# ...

# %%
label=list(x.index)
label
# Out:
# ['Ambassador Classic Nova Diesel',
#  'Audi A3 35 TDI Attraction',
#  'Audi A3 35 TDI Premium',
#  'Audi A3 35 TDI Premium Plus',
#  'Audi A3 35 TDI Technology',
#  'Audi A4 1.8 TFSI',
#  'Audi A4 1.8 TFSI Technology Edition',
#  'Audi A4 2.0 TDI',
#  'Audi A4 2.0 TDI 177  Premium Plus',
#  'Audi A4 2.0 TDI 177  Technology Edition',
#  'Audi A4 2.0 TDI Celebration Edition',
#  'Audi A4 2.0 TDI Multitronic',
#  'Audi A4 2.0 TDI Premium Sport Limited Edition',
#  'Audi A4 2.0 TFSI',
#  'Audi A4 3.0 TDI Quattro',
#  'Audi A4 3.0 TDI Quattro Premium',
#  'Audi A4 3.2 FSI Tiptronic Quattro',
#  'Audi A4 30 TFSI Premium Plus',
#  'Audi A4 35 TDI Premium',
#  'Audi A4 35 TDI Premium Plus',
#  'Audi A4 35 TDI Premium Sport',
#  'Audi A4 35 TDI Technology',
#  'Audi A4 35 TDI Technology Edition',
#  'Audi A4 New 2.0 TDI Multitronic',
#  'Audi A6 2.0 TDI Design Edition',
#  'Audi A6 2.7 TDI',
#  'Audi A6 2.8 FSI',
#  'Audi A6 2011-2015 2.0 TDI',
#  'Audi A6 2011-2015 2.0 TDI Premium Plus',
# ...

# %% [markdown]
# # Univariate Analysis for categorical Data

# %%
df['Location'].value_counts().plot.bar(title='Freq dist of Location')

# %%
label=list(x.index)
count=x.Price
plt.bar(label,count)
plt.show()

# %%
label=list(x.index)
count=x.Price
plt.pie(count,labels=label,autopct='%1.2f%%')
plt.show()

# %%
col_names=['Price','Mileage(kmpl)']
fig, ax = plt.subplots(len(col_names), figsize=(10,12))

for i, col_val in enumerate(col_names):
    sns.distplot(df[col_val], hist=True, ax=ax[i])
    ax[i].set_title('Freq dist '+col_val, fontsize=10)
    ax[i].set_xlabel(col_val, fontsize=8)
    ax[i].set_ylabel('Count', fontsize=8)
plt.show()

# %%
a=df['Price'].dropna()
sns.distplot(a)         
plt.show()

# %% [markdown]
# # Bi-Variate Analysis:
# Bi-variate Analysis finds out the relationship between two variables.We can perform bi-variate analysis for any combination of categorical and continuous variables.

# %%
plt.figure(figsize=(14, 14))
sns.pairplot(data, diag_kind='kde');

# %%
stats.zscore(df['Price'])
# Out:
# array([-0.69093384,  0.27000402, -0.44511253, ..., -0.58813584,
#        -0.61048323, -0.62389166])

# %%
stats.zscore(df['Kilometers_Driven'])
# Out:
# array([ 0.14531489, -0.19436922, -0.13958146, ..., -0.0409635 ,
#        -0.13958146, -0.12862391])

# %% [markdown]
# # Identifying and Treating Missing values

# %%
dup.isnull()
# Out:
#        Name  Location   Year  Kilometers_Driven  Fuel_Type  Transmission  \
# 0     False     False  False              False      False         False
# 1     False     False  False              False      False         False
# 2     False     False  False              False      False         False
# 3     False     False  False              False      False         False
# 4     False     False  False              False      False         False
# ...     ...       ...    ...                ...        ...           ...
# 6014  False     False  False              False      False         False
# 6015  False     False  False              False      False         False
# 6016  False     False  False              False      False         False
# 6017  False     False  False              False      False         False
# 6018  False     False  False              False      False         False
#
#       Owner_Type  Mileage(kmpl)  Engine(CC)  Power(bhp)  Seats  Price  \
# ...

# %%
dup.isnull().sum()
# Out:
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage(kmpl)           2
# Engine(CC)             36
# Power(bhp)             36
# Seats                  42
# Price                   0
# paint_color          2124
# type                 1433
# condition            2565
# dtype: int64

# %%
dup.isnull().values.any()
# Out:
# True

# %% [markdown]
# Now we will fill the missing values using fillna()

# %%
dup.fillna(0)
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
# ...

# %% [markdown]
# # Outliers
# Using  zscore we can find outliers

# %%
a=df['Price']

# %%
z=stats.zscore(a)
a[(z>3)]
# Out:
# 134      54.00
# 168      45.00
# 191      55.76
# 216      45.00
# 264      61.29
#          ...
# 5900     43.30
# 5919    100.00
# 5927     45.52
# 5946     48.00
# 6008     45.00
# Name: Price, Length: 149, dtype: float64

# %%
b=df['Kilometers_Driven']

# %%
z=stats.zscore(b)
b[(z>3)]
# Out:
# 340      775000
# 358      620000
# 1860     720000
# 2328    6500000
# 2823     480000
# 3092     480000
# 4491     445000
# Name: Kilometers_Driven, dtype: int64

# %%
plt.boxplot(a)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x286d2483ec8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x286d2487bc8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x286d2483808>],
#  'medians': [<matplotlib.lines.Line2D at 0x286d2487d48>],
#  'fliers': [<matplotlib.lines.Line2D at 0x286d248bc08>],
#  'means': []}

# %%
plt.boxplot(b)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x286d2db6f48>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x286d2dc6a88>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x286d2db66c8>],
#  'medians': [<matplotlib.lines.Line2D at 0x286d2dc6c08>],
#  'fliers': [<matplotlib.lines.Line2D at 0x286d2d98ac8>],
#  'means': []}

# %%
col_names=['Price','Seats','Mileage(kmpl)','Engine(CC)']

fig, ax = plt.subplots(len(col_names), figsize=(8,40))

for i, col_val in enumerate(col_names):

    sns.boxplot(y=df[col_val], ax=ax[i])
    ax[i].set_title('Box plot - {}'.format(col_val), fontsize=10)
    ax[i].set_xlabel(col_val, fontsize=8)

plt.show()

# %% [markdown]
# # Correlation Matrix
# A correlation matrix is a table showing the value of the correlation coefficient (Correlation coefficients are used in statistics to measure how strong a relationship is between two variables. ) between sets of variables. Each attribute of the dataset is compared with the other attributes to find out the correlation coefficient.

# %%
f, ax = plt.subplots(figsize=(10, 8))
corr = data.corr()
sns.heatmap(corr,xticklabels=corr.columns.values, yticklabels=corr.columns.values,annot=True)
